# %%
import ast
import numpy as np
import pandas as pd

import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim

from copy import deepcopy
from sklearn.model_selection import KFold

# %%
class MLP_100_100_100_regressor(nn.Module):
    def __init__(self):
        super().__init__()

        self.layer1 = nn.Linear(22, 100)  
        self.relu = nn.ReLU()
        self.hidden_layer_relu = nn.Sequential(
            nn.Linear(100,100),
            nn.ReLU(),
            nn.Linear(100,100),
            nn.ReLU(),
            nn.Linear(100,100),
            nn.ReLU()
        )                          
        self.layer2 = nn.Linear(100, 30) 

    def forward(self, x):

        x = self.relu(self.layer1(x))
        x = self.hidden_layer_relu(x)
        logits = self.layer2(x)
        
        return logits

# %%
# abrindo os dados de treinamento
df = pd.read_csv("./../ansatz_result/data.csv")
X = df.drop(columns=["target"]).to_numpy()
y = pd.DataFrame(df['target'].apply(ast.literal_eval).tolist()).to_numpy()
y_regression = y.astype(np.float32)  # Garanta que é float32

# criando o kfold
kf = KFold(n_splits=3, shuffle=True, random_state=42)

# %%
print(y)
# Out:
# [[0.7        0.5        0.72857143 ... 0.71428571 0.72857143 0.71428571]
#  [0.72857143 0.5        0.7        ... 0.68571429 0.7        0.71428571]
#  [0.75714286 0.5        0.75714286 ... 0.75714286 0.77142857 0.77142857]
#  ...
#  [0.52285714 0.5        0.50857143 ... 0.50571429 0.50571429 0.50857143]
#  [0.5        0.5        0.49285714 ... 0.50428571 0.49857143 0.5       ]
#  [0.51714286 0.5        0.52428571 ... 0.49       0.52142857 0.50428571]]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
# implementação de um critério de parada para o modelo parar no ponto "ótimo"
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = float('inf')
        self.early_stop = False
        
    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
# 3. Função para treinar um fold
def train_fold(model, train_loader, val_loader, criterion, optimizer, n_epochs=1000000):
    model.to(device)
    early_stopping = EarlyStopping(patience=10, min_delta=0.0)
    best_model = None
    best_val_loss = 1000000
    
    for epoch in range(n_epochs):
        # Treinamento
        model.train()
        train_loss = 0.0

        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_batch = y_batch.squeeze()  # Converte (batch_size, 1) para (batch_size,)
            
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        # Validação
        model.eval()
        with torch.no_grad():
            val_loss = 0.0

            for X_val, y_val in val_loader:
                X_val, y_val = X_val.to(device), y_val.to(device)
                outputs = model(X_val)
                val_loss += criterion(outputs, y_val).item()
        
        
        val_loss /= len(val_loader)
        
        print(f'Epoch {epoch+1}/{n_epochs} - Train Loss: {train_loss:.4f} - Val Loss: {val_loss:.4f} ')
        
        # Early Stopping
        early_stopping(val_loss)
        if early_stopping.early_stop:
            print(f"Early stopping at epoch {epoch+1}")
            break
            
        # Salvar melhor modelo
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = deepcopy(model.state_dict())
    
    return best_model, best_val_loss

# %%
results = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f"\n=== Fold {fold + 1}/{3} ===")
    
    # Dividir e preparar dados
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y_regression[train_idx], y_regression[val_idx]
    
    train_dataset = TensorDataset(torch.FloatTensor(X_train), torch.FloatTensor(y_train))
    val_dataset = TensorDataset(torch.FloatTensor(X_val), torch.FloatTensor(y_val))
    
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32)
    
    # Inicializar modelo e otimizador
    model = MLP_100_100_100_regressor()
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)  # L2 regularization
    
    # Treinar fold
    best_model, best_mse = train_fold(model, train_loader, val_loader, criterion, optimizer)
    results.append(best_mse)
    
    # Salvar modelo se necessário
    torch.save(best_model, f'./models_salvos/best_model_MLP-100-100-100-regressor_fold{fold+1}.pt')

# 7. Resultados finais
print("\n=== Resultados ===")
print(f" MSE médio: {np.mean(results):.4f} ± {np.std(results):.4f}")
print(f"MSE por fold: {results}")
# Out:
# === Fold 1/3 ===
# Epoch 1/1000000 - Train Loss: 2.8205 - Val Loss: 0.2982
1000000 - Train Loss: 0.0102 - Val Loss: 0.0012
# Epoch 30/1000000 - Train Loss: 0.0105 - Val Loss: 0.0012
# Epoch 31/1000000 - Train Loss: 0.0104 - Val Loss: 0.0012
# Epoch 32/1000000 - Train Loss: 0.0107 - Val Loss: 0.0012
# Epoch 33/1000000 - Train Loss: 0.0103 - Val Loss: 0.0012
# Epoch 34/1000000 - Train Loss: 0.0102 - Val Loss: 0.0012
# Epoch 35/1000000 - Train Loss: 0.0104 - Val Loss: 0.0012
# Epoch 36/1000000 - Train Loss: 0.0106 - Val Loss: 0.0011
# Epoch 37/1000000 - Train Loss: 0.0103 - Val Loss: 0.0012
# Epoch 38/1000000 - Train Loss: 0.0103 - Val Loss: 0.0012
# Epoch 39/1000000 - Train Loss: 0.0098 - Val Loss: 0.0011
# Epoch 40/1000000 - Train Loss: 0.0100 - Val Loss: 0.0012
# Epoch 41/1000000 - Train Loss: 0.0101 - Val Loss: 0.0011
# Epoch 42/1000000 - Train Loss: 0.0100 - Val Loss: 0.0011
# Epoch 43/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 44/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 45/1000000 - Train Loss: 0.0100 - Val Loss: 0.0011
# Epoch 46/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 47/1000000 - Train Loss: 0.0098 - Val Loss: 0.0012
# Epoch 48/1000000 - Train Loss: 0.0101 - Val Loss: 0.0011
# Epoch 49/1000000 - Train Loss: 0.0099 - Val Loss: 0.0012
# Epoch 50/1000000 - Train Loss: 0.0097 - Val Loss: 0.0011
# Epoch 51/1000000 - Train Loss: 0.0101 - Val Loss: 0.0011
# Epoch 52/1000000 - Train Loss: 0.0100 - Val Loss: 0.0011
# Epoch 53/1000000 - Train Loss: 0.0101 - Val Loss: 0.0012
# Epoch 54/1000000 - Train Loss: 0.0098 - Val Loss: 0.0012
# Epoch 55/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 56/1000000 - Train Loss: 0.0097 - Val Loss: 0.0011
# Epoch 57/1000000 - Train Loss: 0.0098 - Val Loss: 0.0011
# Epoch 58/1000000 - Train Loss: 0.0096 - Val Loss: 0.0011
# Epoch 59/1000000 - Train Loss: 0.0099 - Val Loss: 0.0012
# Epoch 60/1000000 - Train Loss: 0.0100 - Val Loss: 0.0011
# Epoch 61/1000000 - Train Loss: 0.0100 - Val Loss: 0.0011
# Epoch 62/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 63/1000000 - Train Loss: 0.0097 - Val Loss: 0.0011
# Epoch 64/1000000 - Train Loss: 0.0096 - Val Loss: 0.0011
# Epoch 65/1000000 - Train Loss: 0.0097 - Val Loss: 0.0011
# Epoch 66/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 67/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 68/1000000 - Train Loss: 0.0101 - Val Loss: 0.0011
# Epoch 69/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 70/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 71/1000000 - Train Loss: 0.0095 - Val Loss: 0.0011
# Epoch 72/1000000 - Train Loss: 0.0099 - Val Loss: 0.0012
# Epoch 73/1000000 - Train Loss: 0.0098 - Val Loss: 0.0011
# Epoch 74/1000000 - Train Loss: 0.0098 - Val Loss: 0.0011
# Epoch 75/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 76/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 77/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 78/1000000 - Train Loss: 0.0094 - Val Loss: 0.0011
# Epoch 79/1000000 - Train Loss: 0.0095 - Val Loss: 0.0011
# Early stopping at epoch 79
#
# === Resultados ===
#  MSE médio: 0.0011 ± 0.0000
# MSE por fold: [0.0011188230819243472, 0.0011469404598756228, 0.001091753856599098]
