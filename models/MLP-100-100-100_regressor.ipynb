# %%
import sys
import os
sys.path.append(os.path.abspath(".."))  # sobe um nível a partir da pasta models/

# %%
import ast
import numpy as np
import pandas as pd

import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim

from copy import deepcopy
from sklearn.model_selection import KFold

from val.Wrapper import ForwardFeatureSelector

# %%
class MLP_100_100_100_regressor(nn.Module):
    def __init__(self, input_len):
        super().__init__()

        self.layer1 = nn.Linear(input_len, 100)  
        self.relu = nn.ReLU()
        self.hidden_layer_relu = nn.Sequential(
            nn.Linear(100,100),
            nn.ReLU(),
            nn.Linear(100,100),
            nn.ReLU(),
            nn.Linear(100,100),
            nn.ReLU()
        )                          
        self.layer2 = nn.Linear(100, 30) 

    def forward(self, x):

        x = self.relu(self.layer1(x))
        x = self.hidden_layer_relu(x)
        logits = self.layer2(x)
        
        return logits

# %%
# abrindo os dados de treinamento
df = pd.read_csv("./../ansatz_result/data.csv")
X = df.drop(columns=["target"]).to_numpy()
y = pd.DataFrame(df['target'].apply(ast.literal_eval).tolist()).to_numpy()
y_regression = y.astype(np.float32)  # Garanta que é float32

# criando o kfold
kf = KFold(n_splits=3, shuffle=True, random_state=42)

# %%
print(y)
# Out:
# [[0.7        0.5        0.72857143 ... 0.71428571 0.72857143 0.71428571]
#  [0.72857143 0.5        0.7        ... 0.68571429 0.7        0.71428571]
#  [0.75714286 0.5        0.75714286 ... 0.75714286 0.77142857 0.77142857]
#  ...
#  [0.52285714 0.5        0.50857143 ... 0.50571429 0.50571429 0.50857143]
#  [0.5        0.5        0.49285714 ... 0.50428571 0.49857143 0.5       ]
#  [0.51714286 0.5        0.52428571 ... 0.49       0.52142857 0.50428571]]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
# implementação de um critério de parada para o modelo parar no ponto "ótimo"
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = float('inf')
        self.early_stop = False
        
    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
# 3. Função para treinar um fold
def train_fold(model, train_loader, val_loader, criterion, optimizer, n_epochs=1000000):
    model.to(device)
    early_stopping = EarlyStopping(patience=10, min_delta=0.0)
    best_model = None
    best_val_loss = 1000000
    
    for epoch in range(n_epochs):
        # Treinamento
        model.train()
        train_loss = 0.0

        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_batch = y_batch.squeeze()  # Converte (batch_size, 1) para (batch_size,)
            
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        # Validação
        model.eval()
        with torch.no_grad():
            val_loss = 0.0

            for X_val, y_val in val_loader:
                X_val, y_val = X_val.to(device), y_val.to(device)
                outputs = model(X_val)
                val_loss += criterion(outputs, y_val).item()
        
        
        val_loss /= len(val_loader)
        
        print(f'Epoch {epoch+1}/{n_epochs} - Train Loss: {train_loss:.4f} - Val Loss: {val_loss:.4f} ')
        
        # Early Stopping
        early_stopping(val_loss)
        if early_stopping.early_stop:
            print(f"Early stopping at epoch {epoch+1}")
            break
            
        # Salvar melhor modelo
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = deepcopy(model.state_dict())
    
    return best_model, best_val_loss

# %%
results = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f"\n=== Fold {fold + 1}/{3} ===")
    
    # Dividir e preparar dados
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y_regression[train_idx], y_regression[val_idx]
    
    train_dataset = TensorDataset(torch.FloatTensor(X_train), torch.FloatTensor(y_train))
    val_dataset = TensorDataset(torch.FloatTensor(X_val), torch.FloatTensor(y_val))
    
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32)
    
    # Inicializar modelo e otimizador
    model = MLP_100_100_100_regressor(22)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.01)
    
    # Treinar fold
    best_model, best_mse = train_fold(model, train_loader, val_loader, criterion, optimizer)
    results.append(best_mse)
    
    # Salvar modelo se necessário
    torch.save(best_model, f'./models_salvos/best_model_MLP-100-100-100-regressor_fold{fold+1}.pt')

# 7. Resultados finais
print("\n=== Resultados ===")
print(f" MSE médio: {np.mean(results):.4f} ± {np.std(results):.4f}")
print(f"MSE por fold: {results}")
# Out:
# === Fold 1/3 ===
# Epoch 1/1000000 - Train Loss: 1.2163 - Val Loss: 0.0262
# Epoch 2/1000000 - Train Loss: 0.0956 - Val Loss: 0.0068
# Epoch 3/1000000 - Train Loss: 0.0530 - Val Loss: 0.0051
# Epoch 4/1000000 - Train Loss: 0.0401 - Val Loss: 0.0044
# Epoch 5/1000000 - Train Loss: 0.0330 - Val Loss: 0.0034
# Epoch 6/1000000 - Train Loss: 0.0255 - Val Loss: 0.0025
# Epoch 7/1000000 - Train Loss: 0.0168 - Val Loss: 0.0020
# Epoch 8/1000000 - Train Loss: 0.0144 - Val Loss: 0.0015
# Epoch 9/1000000 - Train Loss: 0.0111 - Val Loss: 0.0014
# Epoch 10/1000000 - Train Loss: 0.0113 - Val Loss: 0.0014
# Epoch 11/1000000 - Train Loss: 0.0113 - Val Loss: 0.0013
# Epoch 12/1000000 - Train Loss: 0.0106 - Val Loss: 0.0013
# Epoch 13/1000000 - Train Loss: 0.0102 - Val Loss: 0.0012
# Epoch 14/1000000 - Train Loss: 0.0100 - Val Loss: 0.0013
# Epoch 15/1000000 - Train Loss: 0.0098 - Val Loss: 0.0012
# Epoch 16/1000000 - Train Loss: 0.0095 - Val Loss: 0.0012
# Epoch 17/1000000 - Train Loss: 0.0091 - Val Loss: 0.0012
# Epoch 18/1000000 - Train Loss: 0.0098 - Val Loss: 0.0012
# Epoch 19/1000000 - Train Loss: 0.0095 - Val Loss: 0.0013
# Epoch 20/1000000 - Train Loss: 0.0105 - Val Loss: 0.0011
# Epoch 21/1000000 - Train Loss: 0.0089 - Val Loss: 0.0012
# Epoch 22/1000000 - Train Loss: 0.0091 - Val Loss: 0.0011
# Epoch 23/1000000 - Train Loss: 0.0089 - Val Loss: 0.0010
# Epoch 24/1000000 - Train Loss: 0.0089 - Val Loss: 0.0011
# Epoch 25/1000000 - Train Loss: 0.0088 - Val Loss: 0.0012
# Epoch 26/1000000 - Train Loss: 0.0089 - Val Loss: 0.0011
# Epoch 27/1000000 - Train Loss: 0.0087 - Val Loss: 0.0011
# Epoch 28/1000000 - Train Loss: 0.0086 - Val Loss: 0.0011
# Epoch 29/1000000 - Train Loss: 0.0094 - Val Loss: 0.0011
# Epoch 30/1000000 - Train Loss: 0.0092 - Val Loss: 0.0011
# Epoch 31/1000000 - Train Loss: 0.0080 - Val Loss: 0.0011
# Epoch 32/1000000 - Train Loss: 0.0088 - Val Loss: 0.0011
# Epoch 33/1000000 - Train Loss: 0.0080 - Val Loss: 0.0012
# Early stopping at epoch 33
#
# === Fold 2/3 ===
# Epoch 1/1000000 - Train Loss: 1.6731 - Val Loss: 0.1549
# Epoch 2/1000000 - Train Loss: 0.7335 - Val Loss: 0.0383
# Epoch 3/1000000 - Train Loss: 0.1368 - Val Loss: 0.0160
# Epoch 4/1000000 - Train Loss: 0.0912 - Val Loss: 0.0060
# Epoch 5/1000000 - Train Loss: 0.0548 - Val Loss: 0.0070
# Epoch 6/1000000 - Train Loss: 0.0457 - Val Loss: 0.0049
# Epoch 7/1000000 - Train Loss: 0.0370 - Val Loss: 0.0045
# Epoch 8/1000000 - Train Loss: 0.0305 - Val Loss: 0.0031
# Epoch 9/1000000 - Train Loss: 0.0204 - Val Loss: 0.0020
# Epoch 10/1000000 - Train Loss: 0.0148 - Val Loss: 0.0017
# Epoch 11/1000000 - Train Loss: 0.0137 - Val Loss: 0.0015
# Epoch 12/1000000 - Train Loss: 0.0127 - Val Loss: 0.0013
# Epoch 13/1000000 - Train Loss: 0.0121 - Val Loss: 0.0013
# Epoch 14/1000000 - Train Loss: 0.0115 - Val Loss: 0.0013
# Epoch 15/1000000 - Train Loss: 0.0116 - Val Loss: 0.0016
# Epoch 16/1000000 - Train Loss: 0.0123 - Val Loss: 0.0014
# Epoch 17/1000000 - Train Loss: 0.0116 - Val Loss: 0.0013
# Epoch 18/1000000 - Train Loss: 0.0110 - Val Loss: 0.0013
# Epoch 19/1000000 - Train Loss: 0.0102 - Val Loss: 0.0012
# Epoch 20/1000000 - Train Loss: 0.0104 - Val Loss: 0.0011
# Epoch 21/1000000 - Train Loss: 0.0096 - Val Loss: 0.0011
# Epoch 22/1000000 - Train Loss: 0.0099 - Val Loss: 0.0012
# Epoch 23/1000000 - Train Loss: 0.0097 - Val Loss: 0.0012
# Epoch 24/1000000 - Train Loss: 0.0093 - Val Loss: 0.0011
# Epoch 25/1000000 - Train Loss: 0.0089 - Val Loss: 0.0010
# Epoch 26/1000000 - Train Loss: 0.0087 - Val Loss: 0.0010
# Epoch 27/1000000 - Train Loss: 0.0092 - Val Loss: 0.0011
# Epoch 28/1000000 - Train Loss: 0.0091 - Val Loss: 0.0011
# Epoch 29/1000000 - Train Loss: 0.0092 - Val Loss: 0.0011
# Epoch 30/1000000 - Train Loss: 0.0088 - Val Loss: 0.0010
# Epoch 31/1000000 - Train Loss: 0.0085 - Val Loss: 0.0010
# Epoch 32/1000000 - Train Loss: 0.0084 - Val Loss: 0.0010
# Epoch 33/1000000 - Train Loss: 0.0085 - Val Loss: 0.0010
# Epoch 34/1000000 - Train Loss: 0.0088 - Val Loss: 0.0011
# Epoch 35/1000000 - Train Loss: 0.0090 - Val Loss: 0.0010
# Early stopping at epoch 35
#
# === Fold 3/3 ===
# Epoch 1/1000000 - Train Loss: 1.6661 - Val Loss: 0.1196
# Epoch 2/1000000 - Train Loss: 0.5722 - Val Loss: 0.0146
# Epoch 3/1000000 - Train Loss: 0.1063 - Val Loss: 0.0122
# Epoch 4/1000000 - Train Loss: 0.0755 - Val Loss: 0.0070
# Epoch 5/1000000 - Train Loss: 0.0547 - Val Loss: 0.0063
# Epoch 6/1000000 - Train Loss: 0.0471 - Val Loss: 0.0052
# Epoch 7/1000000 - Train Loss: 0.0414 - Val Loss: 0.0047
# Epoch 8/1000000 - Train Loss: 0.0373 - Val Loss: 0.0043
# Epoch 9/1000000 - Train Loss: 0.0322 - Val Loss: 0.0036
# Epoch 10/1000000 - Train Loss: 0.0244 - Val Loss: 0.0024
# Epoch 11/1000000 - Train Loss: 0.0163 - Val Loss: 0.0015
# Epoch 12/1000000 - Train Loss: 0.0122 - Val Loss: 0.0014
# Epoch 13/1000000 - Train Loss: 0.0118 - Val Loss: 0.0014
# Epoch 14/1000000 - Train Loss: 0.0117 - Val Loss: 0.0013
# Epoch 15/1000000 - Train Loss: 0.0115 - Val Loss: 0.0013
# Epoch 16/1000000 - Train Loss: 0.0120 - Val Loss: 0.0013
# Epoch 17/1000000 - Train Loss: 0.0111 - Val Loss: 0.0012
# Epoch 18/1000000 - Train Loss: 0.0104 - Val Loss: 0.0012
# Epoch 19/1000000 - Train Loss: 0.0109 - Val Loss: 0.0012
# Epoch 20/1000000 - Train Loss: 0.0108 - Val Loss: 0.0012
# Epoch 21/1000000 - Train Loss: 0.0110 - Val Loss: 0.0012
# Epoch 22/1000000 - Train Loss: 0.0110 - Val Loss: 0.0012
# Epoch 23/1000000 - Train Loss: 0.0105 - Val Loss: 0.0013
# Epoch 24/1000000 - Train Loss: 0.0108 - Val Loss: 0.0012
# Epoch 25/1000000 - Train Loss: 0.0107 - Val Loss: 0.0012
# Epoch 26/1000000 - Train Loss: 0.0106 - Val Loss: 0.0012
# Epoch 27/1000000 - Train Loss: 0.0102 - Val Loss: 0.0012
# Epoch 28/1000000 - Train Loss: 0.0106 - Val Loss: 0.0012
# Epoch 29/1000000 - Train Loss: 0.0107 - Val Loss: 0.0012
# Epoch 30/1000000 - Train Loss: 0.0103 - Val Loss: 0.0012
# Epoch 31/1000000 - Train Loss: 0.0104 - Val Loss: 0.0012
# Epoch 32/1000000 - Train Loss: 0.0105 - Val Loss: 0.0013
# Epoch 33/1000000 - Train Loss: 0.0105 - Val Loss: 0.0012
# Epoch 34/1000000 - Train Loss: 0.0107 - Val Loss: 0.0012
# Epoch 35/1000000 - Train Loss: 0.0105 - Val Loss: 0.0011
# Epoch 36/1000000 - Train Loss: 0.0110 - Val Loss: 0.0013
# Epoch 37/1000000 - Train Loss: 0.0113 - Val Loss: 0.0012
# Epoch 38/1000000 - Train Loss: 0.0116 - Val Loss: 0.0012
# Epoch 39/1000000 - Train Loss: 0.0110 - Val Loss: 0.0012
# Epoch 40/1000000 - Train Loss: 0.0110 - Val Loss: 0.0012
# Epoch 41/1000000 - Train Loss: 0.0102 - Val Loss: 0.0011
# Epoch 42/1000000 - Train Loss: 0.0102 - Val Loss: 0.0011
# Epoch 43/1000000 - Train Loss: 0.0105 - Val Loss: 0.0012
# Epoch 44/1000000 - Train Loss: 0.0101 - Val Loss: 0.0011
# Epoch 45/1000000 - Train Loss: 0.0100 - Val Loss: 0.0011
# Epoch 46/1000000 - Train Loss: 0.0104 - Val Loss: 0.0011
# Epoch 47/1000000 - Train Loss: 0.0101 - Val Loss: 0.0011
# Epoch 48/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 49/1000000 - Train Loss: 0.0107 - Val Loss: 0.0011
# Epoch 50/1000000 - Train Loss: 0.0107 - Val Loss: 0.0011
# Epoch 51/1000000 - Train Loss: 0.0097 - Val Loss: 0.0011
# Epoch 52/1000000 - Train Loss: 0.0098 - Val Loss: 0.0011
# Epoch 53/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 54/1000000 - Train Loss: 0.0102 - Val Loss: 0.0011
# Epoch 55/1000000 - Train Loss: 0.0099 - Val Loss: 0.0011
# Epoch 56/1000000 - Train Loss: 0.0103 - Val Loss: 0.0013
# Epoch 57/1000000 - Train Loss: 0.0103 - Val Loss: 0.0011
# Epoch 58/1000000 - Train Loss: 0.0106 - Val Loss: 0.0013
# Epoch 59/1000000 - Train Loss: 0.0103 - Val Loss: 0.0012
# Epoch 60/1000000 - Train Loss: 0.0104 - Val Loss: 0.0011
# Epoch 61/1000000 - Train Loss: 0.0101 - Val Loss: 0.0011
# Epoch 62/1000000 - Train Loss: 0.0094 - Val Loss: 0.0011
# Epoch 63/1000000 - Train Loss: 0.0098 - Val Loss: 0.0011
# Epoch 64/1000000 - Train Loss: 0.0095 - Val Loss: 0.0011
# Epoch 65/1000000 - Train Loss: 0.0092 - Val Loss: 0.0011
# Epoch 66/1000000 - Train Loss: 0.0094 - Val Loss: 0.0011
# Epoch 67/1000000 - Train Loss: 0.0096 - Val Loss: 0.0010
# Epoch 68/1000000 - Train Loss: 0.0096 - Val Loss: 0.0011
# Epoch 69/1000000 - Train Loss: 0.0094 - Val Loss: 0.0010
# Epoch 70/1000000 - Train Loss: 0.0092 - Val Loss: 0.0010
# Epoch 71/1000000 - Train Loss: 0.0089 - Val Loss: 0.0011
# Epoch 72/1000000 - Train Loss: 0.0093 - Val Loss: 0.0013
# Epoch 73/1000000 - Train Loss: 0.0100 - Val Loss: 0.0011
# Epoch 74/1000000 - Train Loss: 0.0099 - Val Loss: 0.0013
# Epoch 75/1000000 - Train Loss: 0.0097 - Val Loss: 0.0011
# Epoch 76/1000000 - Train Loss: 0.0093 - Val Loss: 0.0011
# Epoch 77/1000000 - Train Loss: 0.0091 - Val Loss: 0.0011
# Epoch 78/1000000 - Train Loss: 0.0097 - Val Loss: 0.0010
# Epoch 79/1000000 - Train Loss: 0.0095 - Val Loss: 0.0010
# Epoch 80/1000000 - Train Loss: 0.0103 - Val Loss: 0.0011
# Epoch 81/1000000 - Train Loss: 0.0098 - Val Loss: 0.0011
# Epoch 82/1000000 - Train Loss: 0.0093 - Val Loss: 0.0010
# Epoch 83/1000000 - Train Loss: 0.0095 - Val Loss: 0.0010
# Epoch 84/1000000 - Train Loss: 0.0095 - Val Loss: 0.0011
# Epoch 85/1000000 - Train Loss: 0.0095 - Val Loss: 0.0011
# Epoch 86/1000000 - Train Loss: 0.0089 - Val Loss: 0.0010
# Epoch 87/1000000 - Train Loss: 0.0090 - Val Loss: 0.0012
# Epoch 88/1000000 - Train Loss: 0.0095 - Val Loss: 0.0011
# Epoch 89/1000000 - Train Loss: 0.0088 - Val Loss: 0.0010
# Epoch 90/1000000 - Train Loss: 0.0082 - Val Loss: 0.0009
# Epoch 91/1000000 - Train Loss: 0.0081 - Val Loss: 0.0010
# Epoch 92/1000000 - Train Loss: 0.0083 - Val Loss: 0.0009
# Epoch 93/1000000 - Train Loss: 0.0082 - Val Loss: 0.0009
# Epoch 94/1000000 - Train Loss: 0.0084 - Val Loss: 0.0010
# Epoch 95/1000000 - Train Loss: 0.0093 - Val Loss: 0.0010
# Epoch 96/1000000 - Train Loss: 0.0085 - Val Loss: 0.0009
# Epoch 97/1000000 - Train Loss: 0.0082 - Val Loss: 0.0009
# Epoch 98/1000000 - Train Loss: 0.0081 - Val Loss: 0.0011
# Epoch 99/1000000 - Train Loss: 0.0087 - Val Loss: 0.0010
# Epoch 100/1000000 - Train Loss: 0.0083 - Val Loss: 0.0010
# Epoch 101/1000000 - Train Loss: 0.0085 - Val Loss: 0.0009
# Epoch 102/1000000 - Train Loss: 0.0078 - Val Loss: 0.0009
# Epoch 103/1000000 - Train Loss: 0.0075 - Val Loss: 0.0011
# Epoch 104/1000000 - Train Loss: 0.0081 - Val Loss: 0.0010
# Epoch 105/1000000 - Train Loss: 0.0084 - Val Loss: 0.0010
# Epoch 106/1000000 - Train Loss: 0.0078 - Val Loss: 0.0010
# Epoch 107/1000000 - Train Loss: 0.0087 - Val Loss: 0.0009
# Epoch 108/1000000 - Train Loss: 0.0079 - Val Loss: 0.0009
# Epoch 109/1000000 - Train Loss: 0.0073 - Val Loss: 0.0010
# Epoch 110/1000000 - Train Loss: 0.0078 - Val Loss: 0.0009
# Epoch 111/1000000 - Train Loss: 0.0073 - Val Loss: 0.0009
# Epoch 112/1000000 - Train Loss: 0.0080 - Val Loss: 0.0009
# Epoch 113/1000000 - Train Loss: 0.0076 - Val Loss: 0.0009
# Epoch 114/1000000 - Train Loss: 0.0075 - Val Loss: 0.0010
# Epoch 115/1000000 - Train Loss: 0.0078 - Val Loss: 0.0009
# Epoch 116/1000000 - Train Loss: 0.0078 - Val Loss: 0.0010
# Epoch 117/1000000 - Train Loss: 0.0081 - Val Loss: 0.0010
# Epoch 118/1000000 - Train Loss: 0.0085 - Val Loss: 0.0012
# Epoch 119/1000000 - Train Loss: 0.0082 - Val Loss: 0.0009
# Epoch 120/1000000 - Train Loss: 0.0077 - Val Loss: 0.0009
# Epoch 121/1000000 - Train Loss: 0.0076 - Val Loss: 0.0009
# Epoch 122/1000000 - Train Loss: 0.0075 - Val Loss: 0.0009
# Epoch 123/1000000 - Train Loss: 0.0071 - Val Loss: 0.0009
# Early stopping at epoch 123
#
# === Resultados ===
#  MSE médio: 0.0010 ± 0.0001
# MSE por fold: [0.0010468686996318866, 0.0010171871399506927, 0.0008800649375189096]

# %%
from sklearn.metrics import mean_squared_error

selector = ForwardFeatureSelector(
    model=lambda input_dim: MLP_100_100_100_regressor(input_dim),
    model_type='pytorch',
    scoring=mean_squared_error,
    cv=3,
    verbose=1,
    pytorch_optimizer= optim.Adam,
    classification=0,
    maior_score=0
)

# %%
X_new = selector.fit_transform(X, y)
# Out:
# Testing feature set: [0]
# Testing feature set: [1]
# Testing feature set: [2]
# Testing feature set: [3]
# Testing feature set: [4]
# Testing feature set: [5]
# Testing feature set: [6]
# Testing feature set: [7]
# Testing feature set: [8]
# Testing feature set: [9]
# Testing feature set: [10]
# Testing feature set: [11]
# Testing feature set: [12]
# Testing feature set: [13]
# Testing feature set: [14]
# Testing feature set: [15]
# Testing feature set: [16]
# Testing feature set: [17]
# Testing feature set: [18]
# Testing feature set: [19]
# Testing feature set: [20]
# Testing feature set: [21]
# 0
# 0.2801286014402799
# Selected feature: 0 | Score: 0.2801
# Testing feature set: [0, 1]
# Testing feature set: [0, 2]
# Testing feature set: [0, 3]
# Testing feature set: [0, 4]
# Testing feature set: [0, 5]
# Testing feature set: [0, 6]
# Testing feature set: [0, 7]
# Testing feature set: [0, 8]
# Testing feature set: [0, 9]
# Testing feature set: [0, 10]
# Testing feature set: [0, 11]
# Testing feature set: [0, 12]
# Testing feature set: [0, 13]
# Testing feature set: [0, 14]
# Testing feature set: [0, 15]
# Testing feature set: [0, 16]
# Testing feature set: [0, 17]
# Testing feature set: [0, 18]
# Testing feature set: [0, 19]
# Testing feature set: [0, 20]
# Testing feature set: [0, 21]
# 17
# 0.2854930125974966
