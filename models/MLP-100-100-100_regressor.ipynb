# %%
import sys
import os
sys.path.append(os.path.abspath(".."))  # sobe um nível a partir da pasta models/

# %%
import ast
import numpy as np
import pandas as pd

import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim

from copy import deepcopy
from sklearn.model_selection import KFold

from features_selection.Wrapper import ForwardFeatureSelector

# %%
class MLP_100_100_100_regressor(nn.Module):
    def __init__(self, input_len):
        super().__init__()

        self.layer1 = nn.Linear(input_len, 100)  
        self.relu = nn.ReLU()
        self.hidden_layer_relu = nn.Sequential(
            nn.Linear(100,100),
            nn.ReLU(),
            nn.Linear(100,100),
            nn.ReLU(),
            nn.Linear(100,100),
            nn.ReLU()
        )                          
        self.layer2 = nn.Linear(100, 30) 

    def forward(self, x):

        x = self.relu(self.layer1(x))
        x = self.hidden_layer_relu(x)
        logits = self.layer2(x)
        
        return logits

# %%
# abrindo os dados de treinamento
df = pd.read_csv("./../ansatz_result/data.csv")
X = df.drop(columns=["target"]).to_numpy()
y = pd.DataFrame(df['target'].apply(ast.literal_eval).tolist()).to_numpy()
y_regression = y.astype(np.float32)  # Garanta que é float32

# criando o kfold
kf = KFold(n_splits=3, shuffle=True, random_state=42)

# %%
print(y)
# Out:
# [[0.7        0.5        0.72857143 ... 0.71428571 0.72857143 0.71428571]
#  [0.72857143 0.5        0.7        ... 0.68571429 0.7        0.71428571]
#  [0.75714286 0.5        0.75714286 ... 0.75714286 0.77142857 0.77142857]
#  ...
#  [0.52285714 0.5        0.50857143 ... 0.50571429 0.50571429 0.50857143]
#  [0.5        0.5        0.49285714 ... 0.50428571 0.49857143 0.5       ]
#  [0.51714286 0.5        0.52428571 ... 0.49       0.52142857 0.50428571]]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
# implementação de um critério de parada para o modelo parar no ponto "ótimo"
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = float('inf')
        self.early_stop = False
        
    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
# 3. Função para treinar um fold
def train_fold(model, train_loader, val_loader, criterion, optimizer, n_epochs=1000000):
    model.to(device)
    early_stopping = EarlyStopping(patience=10, min_delta=0.0)
    best_model = None
    best_val_loss = 1000000
    
    for epoch in range(n_epochs):
        # Treinamento
        model.train()
        train_loss = 0.0

        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_batch = y_batch.squeeze()  # Converte (batch_size, 1) para (batch_size,)
            
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        # Validação
        model.eval()
        with torch.no_grad():
            val_loss = 0.0

            for X_val, y_val in val_loader:
                X_val, y_val = X_val.to(device), y_val.to(device)
                outputs = model(X_val)
                val_loss += criterion(outputs, y_val).item()
        
        
        val_loss /= len(val_loader)
        
        print(f'Epoch {epoch+1}/{n_epochs} - Train Loss: {train_loss:.4f} - Val Loss: {val_loss:.4f} ')
        
        # Early Stopping
        early_stopping(val_loss)
        if early_stopping.early_stop:
            print(f"Early stopping at epoch {epoch+1}")
            break
            
        # Salvar melhor modelo
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = deepcopy(model.state_dict())
    
    return best_model, best_val_loss

# %%
results = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f"\n=== Fold {fold + 1}/{3} ===")
    
    # Dividir e preparar dados
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y_regression[train_idx], y_regression[val_idx]
    
    train_dataset = TensorDataset(torch.FloatTensor(X_train), torch.FloatTensor(y_train))
    val_dataset = TensorDataset(torch.FloatTensor(X_val), torch.FloatTensor(y_val))
    
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32)
    
    # Inicializar modelo e otimizador
    model = MLP_100_100_100_regressor(22)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.01)
    
    # Treinar fold
    best_model, best_mse = train_fold(model, train_loader, val_loader, criterion, optimizer)
    results.append(best_mse)
    
    # Salvar modelo se necessário
    torch.save(best_model, f'./models_salvos/best_model_MLP-100-100-100-regressor_fold{fold+1}.pt')

# 7. Resultados finais
print("\n=== Resultados ===")
print(f" MSE médio: {np.mean(results):.4f} ± {np.std(results):.4f}")
print(f"MSE por fold: {results}")
# Out:
# === Fold 1/3 ===
# Epoch 1/1000000 - Train Loss: 1.6263 - Val Loss: 0.1026
# Epoch 2/1000000 - Train Loss: 0.4296 - Val Loss: 0.0112
# Epoch 3/1000000 - Train Loss: 0.1007 - Val Loss: 0.0142
# Epoch 4/1000000 - Train Loss: 0.0736 - Val Loss: 0.0065
# Epoch 5/1000000 - Train Loss: 0.0512 - Val Loss: 0.0055
# Epoch 6/1000000 - Train Loss: 0.0401 - Val Loss: 0.0044
# Epoch 7/1000000 - Train Loss: 0.0314 - Val Loss: 0.0032
# Epoch 8/1000000 - Train Loss: 0.0211 - Val Loss: 0.0021
# Epoch 9/1000000 - Train Loss: 0.0147 - Val Loss: 0.0018
# Epoch 10/1000000 - Train Loss: 0.0137 - Val Loss: 0.0016
# Epoch 11/1000000 - Train Loss: 0.0134 - Val Loss: 0.0016
# Epoch 12/1000000 - Train Loss: 0.0130 - Val Loss: 0.0015
# Epoch 13/1000000 - Train Loss: 0.0130 - Val Loss: 0.0015
# Epoch 14/1000000 - Train Loss: 0.0129 - Val Loss: 0.0016
# Epoch 15/1000000 - Train Loss: 0.0121 - Val Loss: 0.0015
# Epoch 16/1000000 - Train Loss: 0.0117 - Val Loss: 0.0014
# Epoch 17/1000000 - Train Loss: 0.0110 - Val Loss: 0.0014
# Epoch 18/1000000 - Train Loss: 0.0106 - Val Loss: 0.0013
# Epoch 19/1000000 - Train Loss: 0.0107 - Val Loss: 0.0013
# Epoch 20/1000000 - Train Loss: 0.0105 - Val Loss: 0.0013
# Epoch 21/1000000 - Train Loss: 0.0102 - Val Loss: 0.0014
# Epoch 22/1000000 - Train Loss: 0.0111 - Val Loss: 0.0014
# Epoch 23/1000000 - Train Loss: 0.0107 - Val Loss: 0.0013
# Epoch 24/1000000 - Train Loss: 0.0101 - Val Loss: 0.0012
# Epoch 25/1000000 - Train Loss: 0.0102 - Val Loss: 0.0012
# Epoch 26/1000000 - Train Loss: 0.0097 - Val Loss: 0.0012
# Epoch 27/1000000 - Train Loss: 0.0097 - Val Loss: 0.0012
# Epoch 28/1000000 - Train Loss: 0.0097 - Val Loss: 0.0012
# Epoch 29/1000000 - Train Loss: 0.0092 - Val Loss: 0.0012
# Epoch 30/1000000 - Train Loss: 0.0094 - Val Loss: 0.0012
# Epoch 62/1000000 - Train Loss: 0.0088 - Val Loss: 0.0010
# Epoch 63/1000000 - Train Loss: 0.0088 - Val Loss: 0.0010
# Epoch 64/1000000 - Train Loss: 0.0089 - Val Loss: 0.0010
# Epoch 65/1000000 - Train Loss: 0.0089 - Val Loss: 0.0011
# Epoch 66/1000000 - Train Loss: 0.0091 - Val Loss: 0.0010
# Epoch 67/1000000 - Train Loss: 0.0090 - Val Loss: 0.0010
# Epoch 68/1000000 - Train Loss: 0.0088 - Val Loss: 0.0010
# Epoch 69/1000000 - Train Loss: 0.0086 - Val Loss: 0.0010
# Epoch 70/1000000 - Train Loss: 0.0085 - Val Loss: 0.0009
# Epoch 71/1000000 - Train Loss: 0.0084 - Val Loss: 0.0010
# Epoch 72/1000000 - Train Loss: 0.0091 - Val Loss: 0.0010
# Epoch 73/1000000 - Train Loss: 0.0086 - Val Loss: 0.0010
# Epoch 74/1000000 - Train Loss: 0.0084 - Val Loss: 0.0009
# Epoch 75/1000000 - Train Loss: 0.0082 - Val Loss: 0.0009
# Epoch 76/1000000 - Train Loss: 0.0080 - Val Loss: 0.0009
# Epoch 77/1000000 - Train Loss: 0.0077 - Val Loss: 0.0009
# Epoch 78/1000000 - Train Loss: 0.0078 - Val Loss: 0.0009
# Epoch 79/1000000 - Train Loss: 0.0077 - Val Loss: 0.0009
# Epoch 80/1000000 - Train Loss: 0.0074 - Val Loss: 0.0009
# Epoch 81/1000000 - Train Loss: 0.0077 - Val Loss: 0.0009
# Epoch 82/1000000 - Train Loss: 0.0077 - Val Loss: 0.0009
# Epoch 83/1000000 - Train Loss: 0.0076 - Val Loss: 0.0009
# Epoch 84/1000000 - Train Loss: 0.0075 - Val Loss: 0.0009
# Epoch 85/1000000 - Train Loss: 0.0074 - Val Loss: 0.0009
# Epoch 86/1000000 - Train Loss: 0.0073 - Val Loss: 0.0010
# Epoch 87/1000000 - Train Loss: 0.0075 - Val Loss: 0.0009
# Epoch 88/1000000 - Train Loss: 0.0075 - Val Loss: 0.0009
# Epoch 89/1000000 - Train Loss: 0.0073 - Val Loss: 0.0009
# Early stopping at epoch 89
#
# === Resultados ===
#  MSE médio: 0.0009 ± 0.0001
# MSE por fold: [0.001016369649732951, 0.0008089412749541225, 0.0008856973327056039]

# %%
from sklearn.metrics import mean_squared_error

selector = ForwardFeatureSelector(
    model=lambda input_dim: MLP_100_100_100_regressor(input_dim),
    model_type='pytorch',
    scoring=mean_squared_error,
    cv=3,
    verbose=1,
    pytorch_optimizer= optim.Adam,
    classification=0,
    maior_score=0
)

# %%
X_new = selector.fit_transform(X, y)
# Out:
# Testing feature set: [0], score: 0.31153911557717645
# Testing feature set: [1], score: 0.3088561070439679
# Testing feature set: [2], score: 0.32121073196742744
# Testing feature set: [3], score: 0.30243914800080984
# Testing feature set: [4], score: 0.3104884999236525
# Testing feature set: [5], score: 0.321622760131756
# Testing feature set: [6], score: 0.2940801547043433
# Testing feature set: [7], score: 0.31151242927834394
# Testing feature set: [8], score: 0.3079430794766846
# Testing feature set: [9], score: 0.30346463164995297
# Testing feature set: [10], score: 0.30853136000607156
# Testing feature set: [11], score: 0.2981548433290417
# Testing feature set: [12], score: 0.3239872315844743
# Testing feature set: [13], score: 0.30705671806355
# Testing feature set: [14], score: 0.30940317194046174
# Testing feature set: [15], score: 0.3108026341577728
# Testing feature set: [16], score: 0.29377285824559823
# Testing feature set: [17], score: 0.3069704740933495
# Testing feature set: [18], score: 0.30652530091784086
# Testing feature set: [19], score: 0.32002537868632097
# Testing feature set: [20], score: 0.3194866503008654
# Testing feature set: [21], score: 0.30227276891553495
# 16
# 0.29377285824559823
# Selected feature: 16 | Score: 0.2938
# Testing feature set: [16, 0], score: 0.3121541599158885
# Testing feature set: [16, 1], score: 0.3133491434963986
# Testing feature set: [16, 2], score: 0.30972671059621676
# Testing feature set: [16, 3], score: 0.29446673611730406
# Testing feature set: [16, 4], score: 0.3134959378730217
# Testing feature set: [16, 5], score: 0.30620661766237567
# Testing feature set: [16, 6], score: 0.3099230195995546
# Testing feature set: [16, 7], score: 0.31082562841981387
# Testing feature set: [16, 8], score: 0.32941208885419476
# Testing feature set: [16, 9], score: 0.3034193597753984
# Testing feature set: [16, 10], score: 0.30696147349692465
# Testing feature set: [16, 11], score: 0.3328958688367733
# Testing feature set: [16, 12], score: 0.28167660490286095
# Testing feature set: [16, 13], score: 0.3059694516160474
# Testing feature set: [16, 14], score: 0.30863854745112534
# Testing feature set: [16, 15], score: 0.2990925656072659
# Testing feature set: [16, 17], score: 0.3152615110590868
# Testing feature set: [16, 18], score: 0.30207036964174444
# Testing feature set: [16, 19], score: 0.3194875758425213
# Testing feature set: [16, 20], score: 0.32738335438534044
# Testing feature set: [16, 21], score: 0.3062502522685229
# 12
# 0.28167660490286095
# Selected feature: 12 | Score: 0.2817
# Testing feature set: [16, 12, 0], score: 0.307170899413106
# Testing feature set: [16, 12, 1], score: 0.3009842630797666
# Testing feature set: [16, 12, 2], score: 0.30511601600433913
# Testing feature set: [16, 12, 3], score: 0.31159343667121725
# Testing feature set: [16, 12, 4], score: 0.3061908548224071
# Testing feature set: [16, 12, 5], score: 0.28321512418940226
# Testing feature set: [16, 12, 6], score: 0.2919063760854048
# Testing feature set: [16, 12, 7], score: 0.3120786108098623
# Testing feature set: [16, 12, 8], score: 0.3001462993771237
# Testing feature set: [16, 12, 9], score: 0.31217458906963874
# Testing feature set: [16, 12, 10], score: 0.28991068424964817
# Testing feature set: [16, 12, 11], score: 0.3117527202146639
# Testing feature set: [16, 12, 13], score: 0.3237506220065102
# Testing feature set: [16, 12, 14], score: 0.3077339191954865
# Testing feature set: [16, 12, 15], score: 0.3164933249157695
# Testing feature set: [16, 12, 17], score: 0.3132631504661952
# Testing feature set: [16, 12, 18], score: 0.30639921723919533
# Testing feature set: [16, 12, 19], score: 0.33352858930303997
# Testing feature set: [16, 12, 20], score: 0.3211324696004071
# Testing feature set: [16, 12, 21], score: 0.2960186193042596
# 5
# 0.28321512418940226
